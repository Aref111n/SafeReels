# %%
import pandas as pd

df =pd.read_csv("/content/reels_collection.csv")
df
# Out:
#           reels_id  Duration (seconds)
# 0     1.000190e+15                  21
# 1     1.000420e+15                   8
# 2     1.001860e+15                  27
# 3     1.001970e+15                  22
# 4     1.001970e+15                   7
# ...            ...                 ...
# 2816  9.973000e+14                  43
# 2817  9.981870e+14                  13
# 2818  9.985400e+14                   9
# 2819  9.995580e+14                   7
# 2820  9.996700e+14                  34
#
# [2821 rows x 2 columns]

# %%
# @title Duration (seconds)

from matplotlib import pyplot as plt
df['Duration (seconds)'].plot(kind='line', figsize=(8, 4), title='Duration (seconds)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df = df.rename(columns={"filename": "reels_id"})

# %%
df
# Out:
#           reels_id  Duration (seconds)
# 0     1.000190e+15                  21
# 1     1.000420e+15                   8
# 2     1.001860e+15                  27
# 3     1.001970e+15                  22
# 4     1.001970e+15                   7
# ...            ...                 ...
# 2816  9.973000e+14                  43
# 2817  9.981870e+14                  13
# 2818  9.985400e+14                   9
# 2819  9.995580e+14                   7
# 2820  9.996700e+14                  34
#
# [2821 rows x 2 columns]

# %%
df_sorted = df.sort_values(by='Duration (seconds)')

# Display the sorted DataFrame
print(df_sorted)
# Out:
#           reels_id  Duration (seconds)
# 2119  5.899290e+14                   1
# 630   1.285350e+15                   3
# 2021  5.611770e+14                   3
# 902   1.588720e+15                   3
# 1131  1.913400e+15                   3
# ...            ...                 ...
# 1888  5.273430e+14                 344
# 2382  8.430440e+15                 366
# 400   1.175280e+15                 404
# 2700  9.376620e+14                 421
# 756   1.452380e+15                 587
#
# [2821 rows x 2 columns]

# %%
df[df['Duration (seconds)']>300]
# Out:
#           reels_id  Duration (seconds)
# 400   1.175280e+15                 404
# 412   1.185720e+15                 322
# 756   1.452380e+15                 587
# 1228  2.253200e+15                 320
# 1277  2.527060e+15                 316
# 1495  3.861140e+15                 306
# 1888  5.273430e+14                 344
# 1984  5.545340e+14                 320
# 2382  8.430440e+15                 366
# 2484  8.741580e+14                 322
# 2700  9.376620e+14                 421

# %%
df = df[df['Duration (seconds)']<=300]

# %%
df['reels_id'] = df['reels_id'].apply(lambda x: f"'{x}" if isinstance(x, (int, float)) else x)
# Out:
# <ipython-input-39-89b55bcc52dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reels_id'] = df['reels_id'].apply(lambda x: f"'{x}" if isinstance(x, (int, float)) else x)

# %%
df
# Out:
#                  reels_id  Duration (seconds)
# 0     '1000190000000000.0                  21
# 1     '1000420000000000.0                   8
# 2     '1001860000000000.0                  27
# 3     '1001970000000000.0                  22
# 4     '1001970000000000.0                   7
# ...                   ...                 ...
# 2816   '997300000000000.0                  43
# 2817   '998187000000000.0                  13
# 2818   '998540000000000.0                   9
# 2819   '999558000000000.0                   7
# 2820   '999670000000000.0                  34
#
# [2810 rows x 2 columns]

# %%
df.to_csv("facebook_reels.csv", index=False)

# %%
df = pd.read_csv("/content/facebook_reels.csv")
df
# Out:
#           Filename   A   B   C  D  E
# 0     1.000190e+15 NaN NaN NaN  0  0
# 1     1.000420e+15 NaN NaN NaN  0  0
# 2     1.001860e+15 NaN NaN NaN  0  0
# 3     1.001970e+15 NaN NaN NaN  0  0
# 4     1.001970e+15 NaN NaN NaN  0  0
# ...            ...  ..  ..  .. .. ..
# 2805  9.973000e+14 NaN NaN NaN  0  0
# 2806  9.981870e+14 NaN NaN NaN  0  0
# 2807  9.985400e+14 NaN NaN NaN  0  0
# 2808  9.995580e+14 NaN NaN NaN  0  0
# 2809  9.996700e+14 NaN NaN NaN  0  0
#
# [2810 rows x 6 columns]

# %%
df['reels_id'] = "'" + df['reels_id'].astype(str) + "'"
# Out:
# <ipython-input-30-86b4fbaed8cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reels_id'] = "'" + df['reels_id'].astype(str) + "'"

# %%
df
# Out:
#                   reels_id  Duration (seconds)
# 0     '1000190000000000.0'                  21
# 1     '1000420000000000.0'                   8
# 2     '1001860000000000.0'                  27
# 3     '1001970000000000.0'                  22
# 4     '1001970000000000.0'                   7
# ...                    ...                 ...
# 2816   '997300000000000.0'                  43
# 2817   '998187000000000.0'                  13
# 2818   '998540000000000.0'                   9
# 2819   '999558000000000.0'                   7
# 2820   '999670000000000.0'                  34
#
# [2810 rows x 2 columns]
